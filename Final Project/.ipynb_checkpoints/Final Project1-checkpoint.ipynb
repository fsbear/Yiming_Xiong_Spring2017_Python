# %% [markdown]
# # Final Project

# %%
import argparse
import json
import pprint
import requests
import sys
import urllib
import csv
import time
import datetime
import pandas as pd
import glob
from pandas.io.json import json_normalize

from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode

# %%
CLIENT_ID = 'gBcvfFpabk3CnzmXKdYe3w'
CLIENT_SECRET = 'K9dIltpo1DH4hTrKy6c7YhxR2bwENElpzqTEaRz44QXxKnImd3cSOnYmhrucVHns'
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.
TOKEN_PATH = '/oauth2/token'
GRANT_TYPE = 'client_credentials'
SEARCH_LIMIT = 50

# %%
def obtaintoken(host, path):
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    assert CLIENT_ID, "Please supply your client_id."
    assert CLIENT_SECRET, "Please supply your client_secret."
    data = urlencode({
        'client_id': CLIENT_ID,
        'client_secret': CLIENT_SECRET,
        'grant_type': GRANT_TYPE,
    })
    headers = {
        'content-type': 'application/x-www-form-urlencoded',
    }
    response = requests.request('POST', url, data=data, headers=headers)
    token = response.json()['access_token']
    return token

token = obtaintoken(API_HOST, TOKEN_PATH)
token
# Out:
# 'Z1C_ixTGccfADwGnwzG5yUE_tqYbJ3Vfj33NrA5Qi_LhXdj_A0idBPo8mP2dHU71s6HAkJuCJDxhH-BJ1WSDno-pyfmit-GNuVB8gPlu2kxjw-tgGZSO6VHnG4H_WHYx'

# %%
def request(host, path, token, url_params=None):
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % token,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
def search(token, term, location):
    

    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT
    }
    return request(API_HOST, SEARCH_PATH, token, url_params=url_params)

def get_business(token, business_id):
    
    business_path = BUSINESS_PATH + business_id

    return request(API_HOST, business_path, token)

def query_api(term, location):
   
#     token = obtaintoken(API_HOST, TOKEN_PATH)
    response = search(token, term, location)

    businesses = response.get('businesses')

    if not businesses:
        print(u'No businesses for {0} in {1} found.'.format(term, location))
        return

    business_id = businesses[0]['id']

    print(u'{0} businesses found, querying business info ' \
        'for the top result "{1}" ...'.format(
            len(businesses), business_id))
    response = get_business(token, business_id)

    print(u'Result for business "{0}" found:'.format(business_id))
    pprint.pprint(response, indent=2)

# %%
response = search(token, 'dinner', 'Boston, MA')
response
with open('data.json', 'w') as outfile:
    json.dump(response, outfile)
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# {'businesses': [{'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'coordinates': {'latitude': 42.36454, 'longitude': -71.05349},
#    'display_phone': '(617) 367-4348',
#    'distance': 2364.994170686,
#    'id': 'pomodoro-boston-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JB1KVFXAhGgm-Un-ONZHUw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '351 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['351 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Pomodoro',
#    'phone': '+16173674348',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 180,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/pomodoro-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 42.3468620018707,
#     'longitude': -71.0761067061516},
#    'display_phone': '(617) 536-6200',
#    'distance': 414.0047427683999,
#    'id': 'the-salty-pig-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0lHTVuN-EiK4Z3fLAqY-9A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '130 Dartmouth St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['130 Dartmouth St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'The Salty Pig',
#    'phone': '+16175366200',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1086,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-salty-pig-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.36458, 'longitude': -71.05344},
#    'display_phone': '(617) 523-9026',
#    'distance': 2372.09634904,
#    'id': 'giacomos-ristorante-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g-lo6_IuVNaiKMCikW4bSQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '355 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['355 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': "Giacomo's Ristorante",
#    'phone': '+16175239026',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 2520,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/giacomos-ristorante-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 42.3496337161869,
#     'longitude': -71.0473232766807},
#    'display_phone': '(617) 553-5900',
#    'distance': 1975.6220825179998,
#    'id': 'row-34-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_ZK68w3t4BC1NRV4W-THAQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '383 Congress St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['383 Congress St', 'Boston, MA 02210'],
#     'state': 'MA',
#     'zip_code': '02210'},
#    'name': 'Row 34',
#    'phone': '+16175535900',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 796,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/row-34-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.3424683399553,
#     'longitude': -71.0994869470596},
#    'display_phone': '(617) 421-4470',
#    'distance': 2396.91800453,
#    'id': 'tapestry-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DhfysfX6PiE2-K-AChRzuw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '69 Kilmarnock St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['69 Kilmarnock St', 'Boston, MA 02215'],
#     'state': 'MA',
#     'zip_code': '02215'},
#    'name': 'Tapestry',
#    'phone': '+16174214470',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 102,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tapestry-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 42.3511377, 'longitude': -71.0776626},
#    'display_phone': '(617) 267-0691',
#    'distance': 649.13453103,
#    'id': 'saltie-girl-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YbBUekue-2E--iW6tsWrgA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '281 Dartmouth St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['281 Dartmouth St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Saltie Girl',
#    'phone': '+16172670691',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 201,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/saltie-girl-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'coordinates': {'latitude': 42.3449355147724,
#     'longitude': -71.0705436362457},
#    'display_phone': '(617) 266-2600',
#    'distance': 328.3279873204,
#    'id': 'barcelona-wine-bar-south-end-boston-6',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j3VIANro3KJMJV-sTdmVYg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '525 Tremont St',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['525 Tremont St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Barcelona Wine Bar South End',
#    'phone': '+16172662600',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 557,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/barcelona-wine-bar-south-end-boston-6?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.3640943, 'longitude': -71.0541488},
#    'display_phone': '(617) 742-0020',
#    'distance': 2288.87094028,
#    'id': 'carmelinas-boston-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJSoZ8eOLSXkBq92py5zMg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '307 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['307 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': "Carmelina's",
#    'phone': '+16177420020',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 581,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/carmelinas-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'coordinates': {'latitude': 42.3589973449707,
#     'longitude': -71.0542373657227},
#    'display_phone': '(617) 948-9800',
#    'distance': 1874.4681433560002,
#    'id': 'bostonia-public-house-boston-4',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SS2qfGN1S6tZTWWmn5gTuA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '131 State St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['131 State St', 'Boston, MA 02109'],
#     'state': 'MA',
#     'zip_code': '02109'},
#    'name': 'Bostonia Public House',
#    'phone': '+16179489800',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 640,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bostonia-public-house-boston-4?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 42.3487198596183,
#     'longitude': -71.0793047980242},
#    'display_phone': '(857) 350-4626',
#    'distance': 669.8645522237999,
#    'id': 'lukes-lobster-back-bay-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fri_Oe_6JlSrKoJjAOTtZA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '75 Exeter Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['75 Exeter Street', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': "Luke's Lobster Back Bay",
#    'phone': '+18573504626',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 598,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lukes-lobster-back-bay-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 42.3409180006501,
#     'longitude': -71.0816150531173},
#    'display_phone': '(617) 536-9500',
#    'distance': 1148.4013023283999,
#    'id': 'srv-boston-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/POA-BHjYiWrZrFGemN0CXA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '569 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['569 Columbus Ave', 'Boston, MA 02118'],
#     'state': 'MA',
#     'zip_code': '02118'},
#    'name': 'SRV Boston',
#    'phone': '+16175369500',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 178,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/srv-boston-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'coordinates': {'latitude': 42.3409677894859,
#     'longitude': -71.0673901926598},
#    'display_phone': '(617) 422-0224',
#    'distance': 827.354130102,
#    'id': 'gaslight-brasserie-boston-4',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LoHqXfoS9vVxjhag4fOIOQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '560 Harrison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['560 Harrison Ave', 'Boston, MA 02118'],
#     'state': 'MA',
#     'zip_code': '02118'},
#    'name': 'Gaslight Brasserie',
#    'phone': '+16174220224',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1608,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/gaslight-brasserie-boston-4?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 42.3413848876953,
#     'longitude': -71.070198059082},
#    'display_phone': '(617) 425-0200',
#    'distance': 728.0099742369999,
#    'id': 'the-gallows-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g4whiNPtAzvF5PeqANrB5Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1395 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['1395 Washington St', 'Boston, MA 02118'],
#     'state': 'MA',
#     'zip_code': '02118'},
#    'name': 'The Gallows',
#    'phone': '+16174250200',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 693,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-gallows-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 42.3529892, 'longitude': -71.0455704},
#    'display_phone': '(617) 737-5051',
#    'distance': 2149.4702313479997,
#    'id': 'committee-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TVoPYrztSq9AXgqbcoaPeQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '50 Northern Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['50 Northern Ave', 'Boston, MA 02210'],
#     'state': 'MA',
#     'zip_code': '02210'},
#    'name': 'Committee',
#    'phone': '+16177375051',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 208,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/committee-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'coordinates': {'latitude': 42.3510322719812,
#     'longitude': -71.0607028752565},
#    'display_phone': '(617) 423-7888',
#    'distance': 936.6873305997999,
#    'id': 'shojo-boston-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8KiRiDfoonaUSQQghT0npQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '9A Tyler St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['9A Tyler St', 'Boston, MA 02111'],
#     'state': 'MA',
#     'zip_code': '02111'},
#    'name': 'Shojo',
#    'phone': '+16174237888',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 542,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/shojo-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 42.3505860446405,
#     'longitude': -71.077508474716},
#    'display_phone': '(617) 369-5609',
#    'distance': 598.3120888188,
#    'id': 'lolita-cocina-and-tequila-bar-boston-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VlNwiC3KdAmFaj1my6jzkQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '271 Dartmouth St',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['271 Dartmouth St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Lolita Cocina & Tequila Bar',
#    'phone': '+16173695609',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1265,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lolita-cocina-and-tequila-bar-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 42.3462394, 'longitude': -71.0750068},
#    'display_phone': '(617) 536-2632',
#    'distance': 356.7731683808,
#    'id': 'coda-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fbxt7WOWg-Wbm3t3TvZSLQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '329 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['329 Columbus Ave', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Coda',
#    'phone': '+16175362632',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 530,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/coda-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 42.3650849, 'longitude': -71.053187},
#    'display_phone': '(617) 742-9600',
#    'distance': 2424.42001579,
#    'id': 'locale-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/82p_oNvNIARbWkeJi53NFw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '352 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['352 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Locale',
#    'phone': '+16177429600',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 225,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/locale-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'coordinates': {'latitude': 42.3552425760626,
#     'longitude': -71.0623372441206},
#    'display_phone': '(617) 338-5333',
#    'distance': 1101.125394862,
#    'id': 'jm-curley-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HYp4UnWHRQ2mSxsUyY7tYQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '21 Temple Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['21 Temple Pl', 'Boston, MA 02111'],
#     'state': 'MA',
#     'zip_code': '02111'},
#    'name': 'Jm Curley',
#    'phone': '+16173385333',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 601,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jm-curley-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 42.3571471, 'longitude': -71.0608731},
#    'display_phone': '(617) 338-7887',
#    'distance': 1333.882710189,
#    'id': 'silvertone-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MGIlLATyXueEoJ_lLtvY7g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '69 Bromfield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['69 Bromfield St', 'Boston, MA 02108'],
#     'state': 'MA',
#     'zip_code': '02108'},
#    'name': 'Silvertone',
#    'phone': '+16173387887',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 750,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/silvertone-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 42.3632711771092,
#     'longitude': -71.0560575975533},
#    'display_phone': '(617) 742-3474',
#    'distance': 2121.050735354,
#    'id': 'neptune-oyster-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oF9AqeZFT3Kg0N4peP_-4A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '63 Salem St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['63 Salem St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Neptune Oyster',
#    'phone': '+16177423474',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 3462,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/neptune-oyster-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.3646699, 'longitude': -71.05382},
#    'display_phone': '(617) 557-9248',
#    'distance': 2355.329923052,
#    'id': 'panza-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/POLprOT9M5PZhBGLZ5dwjg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '326 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['326 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Panza',
#    'phone': '+16175579248',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 940,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/panza-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'coordinates': {'latitude': 42.34133, 'longitude': -71.0569151},
#    'display_phone': '(617) 752-4191',
#    'distance': 1370.297004968,
#    'id': 'moonshine-152-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k0V3tncNKee3qz-fIkgA5Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '152 Dorchester Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['152 Dorchester Ave', 'Boston, MA 02127'],
#     'state': 'MA',
#     'zip_code': '02127'},
#    'name': 'Moonshine 152',
#    'phone': '+16177524191',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 182,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/moonshine-152-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.3496932983398,
#     'longitude': -71.0812225341797},
#    'display_phone': '(617) 536-2020',
#    'distance': 847.2326977819998,
#    'id': 'piattini-boston-3',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YV6OgWTwoenEcRJ5rFHQTg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '226 Newbury St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['226 Newbury St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Piattini',
#    'phone': '+16175362020',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 584,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/piattini-boston-3?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 42.3766634613276,
#     'longitude': -71.0566809028387},
#    'display_phone': '(617) 337-5703',
#    'distance': 3432.8149179839997,
#    'id': 'the-brewers-fork-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FFKeVx74qkhw9CNkEpv8EQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7 Moulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['7 Moulton St', 'Boston, MA 02129'],
#     'state': 'MA',
#     'zip_code': '02129'},
#    'name': "The Brewer's Fork",
#    'phone': '+16173375703',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 181,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-brewers-fork-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 42.3500454, 'longitude': -71.0816971},
#    'display_phone': '(617) 572-3300',
#    'distance': 893.1475542236,
#    'id': 'gre-co-boston-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bHJvMxqxXZr1x1KUdC208A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '225 Newbury St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['225 Newbury St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'Gre.Co',
#    'phone': '+16175723300',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 67,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/gre-co-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.3595754, 'longitude': -71.0513283},
#    'display_phone': '(617) 863-8363',
#    'distance': 2088.86779777,
#    'id': 'state-street-provisions-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mIPu9jhkRx2PAUAN-S0Dtw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '255 State St',
#     'address2': '',
#     'address3': 'Long Wharf',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['255 State St', 'Long Wharf', 'Boston, MA 02109'],
#     'state': 'MA',
#     'zip_code': '02109'},
#    'name': 'State Street Provisions',
#    'phone': '+16178638363',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 165,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/state-street-provisions-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.3653984, 'longitude': -71.0586472},
#    'display_phone': '(617) 823-4478',
#    'distance': 2209.3886954259997,
#    'id': 'ward-8-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/geSeN9h_kDkO2zNRoCNUgQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '90 N Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['90 N Washington St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Ward 8',
#    'phone': '+16178234478',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 301,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ward-8-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.3499185, 'longitude': -71.0470911},
#    'display_phone': '(617) 904-2748',
#    'distance': 2021.4066789799997,
#    'id': 'city-tap-house-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/whtUekQ5F4KZ6sSUr3zS9Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '10 Boston Wharf Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['10 Boston Wharf Rd', 'Boston, MA 02210'],
#     'state': 'MA',
#     'zip_code': '02210'},
#    'name': 'City Tap House',
#    'phone': '+16179042748',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 57,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/city-tap-house-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 42.3369670759542,
#     'longitude': -71.0477377406966},
#    'display_phone': '(617) 917-5626',
#    'distance': 2279.2029911639997,
#    'id': 'loco-taqueria-and-oyster-bar-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FxdrTZ6PkHo-jzTkwPnr_w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '412 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['412 W Broadway', 'Boston, MA 02127'],
#     'state': 'MA',
#     'zip_code': '02127'},
#    'name': 'Loco Taqueria and Oyster Bar',
#    'phone': '+16179175626',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 314,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/loco-taqueria-and-oyster-bar-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'coordinates': {'latitude': 42.3369631861411,
#     'longitude': -71.0758940796503},
#    'display_phone': '(617) 536-4300',
#    'distance': 1268.7742050779998,
#    'id': 'toro-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vavJneJjBulHvZAGit-bdQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1704 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['1704 Washington St', 'Boston, MA 02118'],
#     'state': 'MA',
#     'zip_code': '02118'},
#    'name': 'Toro',
#    'phone': '+16175364300',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 1697,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/toro-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 42.347459, 'longitude': -71.10323},
#    'display_phone': '(617) 421-1910',
#    'distance': 2629.319253382,
#    'id': 'audubon-boston-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-sXXMrqf7X7zu7BQykmfjw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '838 Beacon St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['838 Beacon St', 'Boston, MA 02215'],
#     'state': 'MA',
#     'zip_code': '02215'},
#    'name': 'Audubon Boston',
#    'phone': '+16174211910',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 122,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/audubon-boston-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'coordinates': {'latitude': 42.3640246614391, 'longitude': -71.0541152},
#    'display_phone': '(857) 317-2871',
#    'distance': 2284.39295173,
#    'id': 'scopa-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BnroASO77OjKG9qVZHMNCQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '319 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['319 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Scopa',
#    'phone': '+18573172871',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 88,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/scopa-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'coordinates': {'latitude': 42.35693359375, 'longitude': -71.0709838867188},
#    'display_phone': '(617) 227-2175',
#    'distance': 1011.8429131439999,
#    'id': '75-chestnut-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vB2LY202JYrIQ5Vernsomw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '75 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['75 Chestnut St', 'Boston, MA 02108'],
#     'state': 'MA',
#     'zip_code': '02108'},
#    'name': '75 Chestnut',
#    'phone': '+16172272175',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 357,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/75-chestnut-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'coordinates': {'latitude': 42.3605931357964,
#     'longitude': -71.056273070639},
#    'display_phone': '(857) 991-1483',
#    'distance': 1876.840310516,
#    'id': 'koy-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EWOtR6_NWH8G9k1WjSKrjg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '16 North St',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['16 North St', 'Boston, MA 02109'],
#     'state': 'MA',
#     'zip_code': '02109'},
#    'name': 'Koy',
#    'phone': '+18579911483',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 243,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/koy-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 42.3372077941895,
#     'longitude': -71.0437545776367},
#    'display_phone': '(617) 622-5700',
#    'distance': 2550.45467322,
#    'id': 'publico-street-bistro-and-garden-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8TTPHrI2DHig-wZceJ1TeA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '11 Dorchester St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['11 Dorchester St', 'Boston, MA 02127'],
#     'state': 'MA',
#     'zip_code': '02127'},
#    'name': 'Publico Street Bistro & Garden',
#    'phone': '+16176225700',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 31,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/publico-street-bistro-and-garden-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 42.34406, 'longitude': -71.077732},
#    'display_phone': '(617) 536-5723',
#    'distance': 679.0427148041999,
#    'id': 'giacomos-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jlXnSdPsUbtn2Xdjgik9sw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '431 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['431 Columbus Ave', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': "Giacomo's",
#    'phone': '+16175365723',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 929,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/giacomos-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 42.36105, 'longitude': -71.063986},
#    'display_phone': '(857) 350-3344',
#    'distance': 1584.90619545,
#    'id': 'the-tip-tap-room-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F-q37O7201QO8CO0dZ7jcQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '138 Cambridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['138 Cambridge St', 'Boston, MA 02114'],
#     'state': 'MA',
#     'zip_code': '02114'},
#    'name': 'The Tip Tap Room',
#    'phone': '+18573503344',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 504,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-tip-tap-room-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'coordinates': {'latitude': 42.3609285960884,
#     'longitude': -71.056898076297},
#    'display_phone': '(617) 367-0033',
#    'distance': 1872.4107631,
#    'id': 'the-tap-trailhouse-boston-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uObo--CAqOnRFArqtT1RTg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '19 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['19 Union St', 'Boston, MA 02108'],
#     'state': 'MA',
#     'zip_code': '02108'},
#    'name': 'The Tap Trailhouse',
#    'phone': '+16173670033',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 221,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/the-tap-trailhouse-boston-2?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'coordinates': {'latitude': 42.3474013, 'longitude': -71.0799231},
#    'display_phone': '(617) 536-1234',
#    'distance': 715.2097988657999,
#    'id': 'porto-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NDIW1cVyYSFXOK2S3TOxCg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'Ring Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['Ring Rd', 'Boston, MA 02199'],
#     'state': 'MA',
#     'zip_code': '02199'},
#    'name': 'Porto',
#    'phone': '+16175361234',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 122,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/porto-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.3498153686523,
#     'longitude': -71.1334228515625},
#    'display_phone': '(617) 208-8925',
#    'distance': 5114.578436664,
#    'id': 'hopewell-bar-and-kitchen-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zaE8vcxTB_yhDK47E1xCwg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1277 Commonwealth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['1277 Commonwealth Ave', 'Boston, MA 02134'],
#     'state': 'MA',
#     'zip_code': '02134'},
#    'name': 'Hopewell Bar & Kitchen',
#    'phone': '+16172088925',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 106,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/hopewell-bar-and-kitchen-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 42.35827, 'longitude': -71.06245},
#    'display_phone': '(617) 742-4900',
#    'distance': 1351.3664994819999,
#    'id': 'scollay-square-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P9T6OOOAUnTvtRHC1wrekQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '21 Beacon St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['21 Beacon St', 'Boston, MA 02108'],
#     'state': 'MA',
#     'zip_code': '02108'},
#    'name': 'Scollay Square',
#    'phone': '+16177424900',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 472,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/scollay-square-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'coordinates': {'latitude': 42.3446991683707,
#     'longitude': -71.0713935252701},
#    'display_phone': '(617) 423-0069',
#    'distance': 349.7446817054,
#    'id': 'the-beehive-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Tv1INsbe23hL6HaK4pdPAA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '541 Tremont St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['541 Tremont St', 'Boston, MA 02116'],
#     'state': 'MA',
#     'zip_code': '02116'},
#    'name': 'The Beehive',
#    'phone': '+16174230069',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 1790,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-beehive-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 42.3494633823329,
#     'longitude': -71.134942010915},
#    'display_phone': '(617) 903-3638',
#    'distance': 5237.761504548,
#    'id': 'the-glenville-stops-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GwTKiZw1_1dajAdSJqXd_Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '87 Glenville Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['87 Glenville Ave', 'Boston, MA 02134'],
#     'state': 'MA',
#     'zip_code': '02134'},
#    'name': 'The Glenville Stops',
#    'phone': '+16179033638',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 201,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-glenville-stops-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'coordinates': {'latitude': 42.3438187315924,
#     'longitude': -71.066250270967},
#    'display_phone': '(617) 542-5200',
#    'distance': 606.9695333487999,
#    'id': 'myers-and-chang-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7V0S4K2LNd7hsgZMNET_9A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1145 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['1145 Washington St', 'Boston, MA 02118'],
#     'state': 'MA',
#     'zip_code': '02118'},
#    'name': 'Myers & Chang',
#    'phone': '+16175425200',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1201,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/myers-and-chang-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.3631202, 'longitude': -71.0549297},
#    'display_phone': '(617) 248-6800',
#    'distance': 2165.793606034,
#    'id': 'bricco-boston-6',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XBFzGXGf1Qh8HcZNHMj8kA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '241 Hanover St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['241 Hanover St', 'Boston, MA 02113'],
#     'state': 'MA',
#     'zip_code': '02113'},
#    'name': 'Bricco',
#    'phone': '+16172486800',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 639,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bricco-boston-6?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'french', 'title': 'French'}],
#    'coordinates': {'latitude': 42.3609838, 'longitude': -71.0680064},
#    'display_phone': '(617) 725-8855',
#    'distance': 1485.2610769116,
#    'id': 'ma-maison-boston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2zDVK36NGAAW6LGKDJgiqQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '272 Cambridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['272 Cambridge St', 'Boston, MA 02114'],
#     'state': 'MA',
#     'zip_code': '02114'},
#    'name': 'Ma Maison',
#    'phone': '+16177258855',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 58,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ma-maison-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.35221, 'longitude': -71.05905},
#    'display_phone': '(617) 993-0750',
#    'distance': 1116.0175030189998,
#    'id': 'townsman-boston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1hP8YtmQ_MCzZRSeEvcDug/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '120 Kingston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['120 Kingston St', 'Boston, MA 02111'],
#     'state': 'MA',
#     'zip_code': '02111'},
#    'name': 'Townsman',
#    'phone': '+16179930750',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 208,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/townsman-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'coordinates': {'latitude': 42.3610800091721,
#     'longitude': -71.0570718850568},
#    'display_phone': '(617) 248-8835',
#    'distance': 1876.645097574,
#    'id': 'saus-boston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U_GZbsZdQYeoFwWmKdRg_g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '33 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['33 Union St', 'Boston, MA 02108'],
#     'state': 'MA',
#     'zip_code': '02108'},
#    'name': 'Saus',
#    'phone': '+16172488835',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 976,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/saus-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 42.35067, 'longitude': -71.04846},
#    'display_phone': '(617) 737-1234',
#    'distance': 1893.4548148079998,
#    'id': 'sportello-boston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/geHArT2KZffi1WN9HkeKNg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '348 Congress St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'country': 'US',
#     'display_address': ['348 Congress St', 'Boston, MA 02210'],
#     'state': 'MA',
#     'zip_code': '02210'},
#    'name': 'Sportello',
#    'phone': '+16177371234',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 685,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/sportello-boston?adjust_creative=gBcvfFpabk3CnzmXKdYe3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gBcvfFpabk3CnzmXKdYe3w'}],
#  'region': {'center': {'latitude': 42.34784169448538,
#    'longitude': -71.07124328613281}},
#  'total': 4017}

# %%
# response = search(token, 'dinner', 'Boston, MA')
# response
# with open('data.json', 'w') as outfile:
#     json.dump(response, outfile)
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...

# %%
d = datetime.datetime(2017,4,24,1,0,0)
unixtime = time.mktime(d.timetuple())
unixtime=int(unixtime)

# %%
def findallresult():
    page = 0
    url_params = {
                'term': '',
                'location': 'Boston, MA',
                'limit': SEARCH_LIMIT,
                'open_at':unixtime,               # Unix Timestamp
                'offset':0
            }
    response1 = request(API_HOST, SEARCH_PATH, token, url_params=url_params)
    with open('data/midnightsnack/page0.json', 'a') as outfile:
        json.dump(response1, outfile)
    
    
    
    
    
    
    while (page < (response1['total']/50)):
#    print 'The count is:', count
        page = page + 1
        url_params = {
                'term': '',
                'location': 'Boston, MA',
                'limit': SEARCH_LIMIT,
                'open_at':unixtime,               # Unix Timestamp
                'offset':50*page

            }

        response = request(API_HOST, SEARCH_PATH, token, url_params=url_params)
        with open('data/midnightsnack/page'+ str(page) +'.json', 'a') as outfile:
            json.dump(response, outfile)

# %%
findallresult()
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...

# %%
# page=19
# while (page < (1239/50)):
# #    print 'The count is:', count
#         page = page + 1
#         url_params = {
#                 'term': '',
#                 'location': 'Boston, MA',
#                 'limit': SEARCH_LIMIT,
#                 'open_at':unixtime,               # Unix Timestamp
#                 'offset':50*page

#             }

#         response = request(API_HOST, SEARCH_PATH, token, url_params=url_params)
#         with open('data/midnightsnack/page'+ str(page) +'.json', 'a') as outfile:
#             json.dump(response, outfile)

# %%
pathList = []
for filepath in glob.glob('/Users/xiongyiming/Documents/INFO7374Python/Final Project/data/midnightsnack/*.json'):
    pathList.append(filepath)

# %%
with open('/Users/xiongyiming/Documents/INFO7374Python/Final Project/data/midnightsnack/page1.json') as data_file:    
    datajson = json.load(data_file)
    dfsu = json_normalize(datajson['businesses'])
    
dfsu.columns
# Out:
# Index(['categories', 'coordinates.latitude', 'coordinates.longitude',
#        'display_phone', 'distance', 'id', 'image_url', 'is_closed',
#        'location.address1', 'location.address2', 'location.address3',
#        'location.city', 'location.country', 'location.display_address',
#        'location.state', 'location.zip_code', 'name', 'phone', 'price',
#        'rating', 'review_count', 'transactions', 'url'],
#       dtype='object')

# %%
df = pd.DataFrame()
for file in pathList:
    with open(file) as data_file:    
        datajson = json.load(data_file)
        if 'businesses' in datajson:
            df1 = json_normalize(datajson['businesses'])
            df1 = df1.reindex(columns=dfsu.columns)
            df2 = df1[['name','distance', 'price', 'rating', 'review_count', 'location.display_address']]
            df = pd.concat([df,df2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-e8836735bc11> in <module>()
#       3     with open(file) as data_file:
#       4         datajson = json.load(data_file)
# ----> 5         df1 = json_normalize(datajson['businesses'])
#       6         df1 = df1.reindex(columns=dfsu.columns)
#       7         df2 = df1[['name','distance', 'price', 'rating', 'review_count', 'location.display_address']]
#
# KeyError: 'businesses'

# %%
df.to_csv('output_path.csv',index=False,header=False)

# %%
len(df['name'].unique())
# Out:
# 50
