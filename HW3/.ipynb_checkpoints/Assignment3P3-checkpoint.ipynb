# %% [markdown]
# #  Assignment3P3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/cricket_matches.csv')
df[:2]
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
#
#                                              result  \
# 0  Durham won by 6 wickets (with 5 balls remaining)
# 1                           Hampshire won by 5 runs
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
#
#                venue        round       home             away     winner  \
# 0  Chester-le-Street  North Group     Durham  Nottinghamshire     Durham
# 1        Southampton  South Group  Hampshire           Sussex  Hampshire
#
#    win_by_runs   ...    innings1_wickets  innings1_overs_batted  \
# 0          NaN   ...                 7.0                   20.0
# 1          5.0   ...                10.0                   19.4
#
# ...

# %%
df1 = df[df['home'] == df['winner']]
df1.head()
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
# 3  South Group:Surrey v Middlesex at The Oval- Ju...
# 4  Midlands/Wales/West Group:Worcestershire v Nor...
# 5  Midlands/Wales/West Group:Gloucestershire v Wo...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# 1                            Hampshire won by 5 runs
# 3   Surrey won by 4 wickets (with 4 balls remaining)
# 4  Worcestershire won by 1 wicket (with 2 balls r...
# 5  Gloucestershire won by 4 wickets (with 5 balls...
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# 3  Middlesex 155 (20/20 ov); Surrey 158/6 (19.2/2...  13/06/2003
# ...

# %%
# df2 = df1[df1['home'] == df1['innings2']]
df1['WinnerScore'] = np.where(df1['home'] == df1['innings2'], df1['innings2_runs'], df1['innings1_runs'])
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df2 = df1[['home','WinnerScore']]
df2.head()
# Out:
#               home  WinnerScore
# 0           Durham        160.0
# 1        Hampshire        153.0
# 3           Surrey        158.0
# 4   Worcestershire        151.0
# 5  Gloucestershire        126.0

# %%
dffinal = pd.DataFrame(df2.groupby(['home'])['WinnerScore'].mean())
dffinal
# Out:
#                                        WinnerScore
# home
# Abahani Limited                         172.000000
# Abbottabad Falcons                      139.454545
# Abbottabad Region                       182.666667
# Abbottabad Rhinos                       165.000000
# Adelaide Strikers                       163.111111
# Afghanistan                             145.560976
# Andhra                                  130.692308
# Antigua                                 146.000000
# Antigua Hawksbills                      106.000000
# Antigua and Barbuda                     153.000000
# Assam                                   139.000000
# Auckland                                164.257143
# Australia                               154.787879
# Australia A                             174.000000
# Azad Jammu & Kashmir Region             123.000000
# Badureliya Sports Club                  155.000000
# Bahawalpur Region                       154.600000
# ...

# %%
dffinal = dffinal.sort_values(['WinnerScore'], ascending = False)
dffinal.head()
# Out:
#                       WinnerScore
# home
# New Zealand A               227.0
# Baluchistan                 217.0
# India A                     214.0
# Northerns (Zimbabwe)        198.5
# Port Qasim Authority        190.0

# %%
dffinal.to_csv('Assignment3P3.csv')
