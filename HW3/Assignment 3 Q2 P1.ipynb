# %% [markdown]
# # Assignment 3 Q2 P1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/employee_compensation.csv')
df.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
# ...

# %%
df1 = df[['Organization Group', 'Department', 'Total Compensation']]
df1.head()
# Out:
#                          Organization Group  \
# 0   Public Works, Transportation & Commerce
# 1                          Community Health
# 2  Human Welfare & Neighborhood Development
# 3          General Administration & Finance
# 4                      Culture & Recreation
#
#                           Department  Total Compensation
# 0                 Airport Commission           143916.66
# 1                      Public Health           107914.16
# 2  Department of the Status of Women              267.28
# 3                    Human Resources             2519.13
# 4     Recreation and Park Commission             1726.68

# %%
df2 = df1.copy()

df2.set_index(['Organization Group', 'Department'], inplace=True)
df2.sort_values(by = "Organization Group", inplace=True)
df2

# df.groupby(df.columns, axis=1).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Organization Group'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-2253fb06a701> in <module>()
#       2
# ...

# %%
df2 = df1.sort_values(by = ['Total Compensation'], ascending= False )
df2
# Out:
#                               Organization Group  \
# 137989          General Administration & Finance
# 211747          General Administration & Finance
# 70143           General Administration & Finance
# 11897           General Administration & Finance
# 334515                         Public Protection
# 324895          General Administration & Finance
# 49158           General Administration & Finance
# 103817          General Administration & Finance
# 270687                         Public Protection
# 108329          General Administration & Finance
# 66386           General Administration & Finance
# 239757                         Public Protection
# 56641                          Public Protection
# 254319   Public Works, Transportation & Commerce
# 99514           General Administration & Finance
# 218017                          Community Health
# 306638                         Public Protection
# 162525                         Public Protection
# ...
