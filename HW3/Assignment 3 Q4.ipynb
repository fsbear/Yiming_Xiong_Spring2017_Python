# %% [markdown]
# # Assignment 3 Q4

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/movies_awards.csv')
df.columns
# Out:
# Index(['totalSeasons', 'Plot', 'Rated', 'Response', 'Language', 'Title',
#        'Country', 'Writer', 'Metascore', 'imdbRating', 'Director', 'Released',
#        'Actors', 'Year', 'Genre', 'Awards', 'Runtime', 'Type', 'Poster',
#        'imdbVotes', 'imdbID'],
#       dtype='object')

# %%
df1 = df.dropna(subset=['Awards'])
df1
# Out:
#       totalSeasons                                               Plot  \
# 3             none  A historical classic drama in three acts; reto...
# 4             none  A father (Williams) suspects his son (Jackson)...
# 5             none  Four perky; clueless cheerleaders from the Hap...
# 6             none  Sandrine; a woman in her thirties gets tired o...
# 7             none  A rivalry develops between a showbiz veteran a...
# 11            none  At Pacific Palisades High; a poor Latino falls...
# 13            none     Love is complex and relationships deteriorate.
# 15            none  An older British reporter vies with a young U....
# 18            none  The neighborhood La Estrella; in Bogotá; is in...
# 24            none  A psychologically troubled novelty supplier is...
# 25            none  Great and important movie about the German-Ger...
# 28               1                                                NaN
# ...
